# %% [markdown]
# # Support Vector Machine

# %%
from PIL import Image
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from sklearn import datasets, svm, linear_model
matplotlib.style.use('bmh')
matplotlib.rcParams['figure.figsize']=(10,7)

# %%
def et24code(w):
    """parse Eten Chinese 24 font to np.array"""
    a = np.frombuffer(w.encode('big5'), dtype='uint8')
    h, l = np.int32(a).reshape(-1, 2).T
    c = (h-161)*157 + l - np.where(l<161, 63, 97)
    return c - np.where(c<=5872, 472, 6281 )

f24 = np.fromfile('data/STDFONT.24K', dtype='uint8')
f24 = np.unpackbits(f24).reshape(-1, 24, 24)*255
f24 = np.repeat(f24[..., None], axis=3, repeats=3)
pixels = 255-f24[et24code("仙")].reshape(-1,24,3)
Image.fromarray(pixels).resize((300,300), Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
# other available images
#pixels = np.array(Image.open('img/smw_yoshi_input.png'))
#pixels = np.array(Image.open('img/invaders_02_input.png'))
#Image.fromarray(pixels).resize((300,300), Image.NEAREST)

# %%
palette =  list(set(tuple(x) for x in pixels.reshape(-1, 3)))
palette
# Out:
# [(0, 0, 0), (255, 255, 255)]

# %%
reverse_palette = {c:i for i, c in enumerate(palette)}

# %%
h, w = pixels.shape[:2]
X = np.mgrid[0:h, 0:w].reshape(2, -1).T
y = np.array([reverse_palette[tuple(x)] for x in pixels.reshape(-1,3)])

# %%
X = X.astype('float64')

# %%
X=np.concatenate([X, X+[.1,.1], X+[.1,-.1], X+[-.1,.1], X+[-.1,-.1]])
y = np.concatenate([y,y,y,y,y])

# %%
from matplotlib.colors import LinearSegmentedColormap
cm= LinearSegmentedColormap.from_list(
        "cmm", np.array(palette)/255 )
matplotlib.rcParams['figure.figsize']=(10,10*h/w)

# %%
clf=svm.NuSVC(nu=0.01, kernel='poly', degree=5,
            decision_function_shape='ovr', gamma=1/10)
X_mean = X.mean(axis=0,keepdims=True)
X_std = X.std()/10
clf.fit((X-X_mean)/X_std, y)

# 邊界
# boundary
x_min, y_min = X.min(axis=0)-1
x_max, y_max = X.max(axis=0)+1

# 座標點
# grid points
grid  = np.mgrid[x_min:x_max:800j, y_min:y_max:800j]
# grid.shape = (2, 200, 200)

# 在座標點 算出 svm 的判斷函數
# calculate the decision function at the grid points
Z = clf.predict( (grid.reshape(2, -1).T-X_mean)/X_std)

# %%
Z  = Z.reshape(grid.shape[1:])
plt.pcolormesh(grid[1], h-grid[0], Z, cmap=cm, alpha=1);

# %% [markdown]
# # The following examples, provided in an as-is basis

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
#clf = BaggingClassifier(KNeighborsClassifier(), max_samples=0.5, max_features=1.)

clf=MLPClassifier(hidden_layer_sizes=(256,64), learning_rate_init=1e-3, max_iter=1500, solver="lbfgs")
#clf = BaggingClassifier(MLPClassifier(hidden_layer_sizes=(512,), learning_rate_init=1e-3, max_iter=1000, solver="lbfgs"), max_samples=0.5, max_features=1.)

X_mean = X.mean(axis=0,keepdims=True)
X_std = X.std(keepdims=True)
W = (X - X_mean)/X_std
X2 = np.concatenate( [W, W**2, (W[:, 0]*W[:, 1])[:, None] ], axis= 1)
X2_mean = X2.mean(axis=0,keepdims=True)
X2_std = X2.std(keepdims=True)

clf.fit((X2-X2_mean)/X2_std, y)

# 邊界
x_min, y_min = X.min(axis=0)-1
x_max, y_max = X.max(axis=0)+1

# 座標點
grid  = np.mgrid[x_min:x_max:800j, y_min:y_max:800j]
W = (grid.reshape(2, -1).T - X_mean)/X_std
W2 = np.concatenate( [W, W**2,  (W[:, 0]*W[:, 1])[:, None] ], axis= 1)
# grid.shape = (2, 200, 200)

# 在座標點 算出 svm 的判斷函數
Z = clf.predict( (W2-X2_mean)/X2_std )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 33
#      29 W2 = np.concatenate( [W, W**2,  (W[:, 0]*W[:, 1])[:, None] ], axis= 1)
#      30 # grid.shape = (2, 200, 200)
#      31
#      32 # 在座標點 算出 svm 的判斷函數
# ---> 33 Z = clf.predict( (W2-X2_mean)/X2_std )
#
# File c:\Users\AaronWu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1163, in MLPClassifier.predict(self, X)
#    1150 """Predict using the multi-layer perceptron classifier.
#    1151
#    1152 Parameters
#    (...)
#    1160     The predicted classes.
#    1161 """
#    1162 check_is_fitted(self)
# -> 1163 return self._predict(X)
#
# File c:\Users\AaronWu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1167, in MLPClassifier._predict(self, X, check_input)
#    1165 def _predict(self, X, check_input=True):
#    1166     """Private predict method with optional input validation"""
# -> 1167     y_pred = self._forward_pass_fast(X, check_input=check_input)
#    1169     if self.n_outputs_ == 1:
#    1170         y_pred = y_pred.ravel()
#
# File c:\Users\AaronWu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:214, in BaseMultilayerPerceptron._forward_pass_fast(self, X, check_input)
#     212 hidden_activation = ACTIVATIONS[self.activation]
#     213 for i in range(self.n_layers_ - 1):
# --> 214     activation = safe_sparse_dot(activation, self.coefs_[i])
#     215     activation += self.intercepts_[i]
#     216     if i != self.n_layers_ - 2:
#
# File c:\Users\AaronWu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\extmath.py:208, in safe_sparse_dot(a, b, dense_output)
#     204 else:
#     205     ret = a @ b
#     207 if (
# --> 208     sparse.issparse(a)
#     209     and sparse.issparse(b)
#     210     and dense_output
#     211     and hasattr(ret, "toarray")
#     212 ):
#     213     return ret.toarray()
#     214 return ret
#
# File c:\Users\AaronWu\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\_base.py:1335, in issparse(x)
#    1329     """A namespace class to separate sparray from spmatrix"""
#    1332 sparray.__doc__ = _spbase.__doc__
# -> 1335 def issparse(x):
#    1336     """Is `x` of a sparse array or sparse matrix type?
#    1337
#    1338     Parameters
#    (...)
#    1359     False
#    1360     """
#    1361     return isinstance(x, _spbase)
#
# KeyboardInterrupt:

# %%
Z2 = Z.reshape(grid.shape[1:])[::, ::]

# %%
Image.fromarray(np.uint8([palette[z] for z in Z2.ravel()]).reshape(Z2.shape+(3,)))

# %%
Z_bool = Z.reshape(grid.shape[1:]) > 0
plt.pcolormesh(grid[1], h-grid[0], Z_bool, cmap=cm, alpha=1);

# %%
    plt.pcolormesh(grid[1], h-grid[0], Z>0, cmap=cm, alpha=1);

# %%
plt.pcolormesh(grid[1], h-grid[0], Z.argmax(axis=2), cmap=cm, alpha=1);

# %%
plt.pcolormesh(grid[1], h-grid[0], Z.argmax(axis=2), cmap=cm, alpha=1);

# %%
plt.pcolormesh(grid[1], h-grid[0], Z.argmax(axis=2), cmap=cm, alpha=1);

# %%
plt.pcolormesh(grid[1], h-grid[0], Z.argmax(axis=2), cmap=cm, alpha=1);

# %%
plt.pcolormesh(grid[1], h-grid[0], Z.argmax(axis=2), cmap=cm, alpha=1);

# %%
plt.pcolormesh(grid[1], h-grid[0], Z.argmax(axis=2), cmap=cm, alpha=1);

# %%
plt.pcolormesh(grid[1], h-grid[0], Z.argmax(axis=2), cmap=cm, alpha=1);
